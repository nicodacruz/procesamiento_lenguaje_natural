# %% [markdown]
# # Procesamiento de Lenguaje Natural
# ## Desafío 2
#
# - Tomar un ejemplo de los bots utilizados (uno de los dos) y construir el propio.
# - Sacar conclusiones de los resultados.
#
# IMPORTANTE: Recuerde para la entrega del ejercicio debe quedar registrado en el colab las preguntas y las respuestas del BOT para que podamos evaluar el desempeño final.

# %%
import json
import string
import random
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('punkt_tab') # <-- CORRECCIÓN: Añadido para solucionar el LookupError
nltk.download('wordnet')
nltk.download('omw-1.4')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# Creo un archivo intents.json con las intenciones, patrones y respuestas para nuestro bot. La idea es armar un bot de información básica para la facultad.

# %%
# defino el contenido del JSON como un string
json_content = """
{
  "intents": [
    {
      "tag": "saludo",
      "patterns": ["Hola", "Como estas?", "Hay alguien ahi?", "Buen dia", "Buenas tardes"],
      "responses": ["Hola!", "Hola, ¿en qué puedo ayudarte?", "¡Buen día! ¿Qué necesitas saber?"]
    },
    {
      "tag": "despedida",
      "patterns": ["Chau", "Adios", "Hasta luego", "Nos vemos", "Tengo que irme"],
      "responses": ["¡Hasta luego! Que tengas un buen día.", "Adiós, ¡vuelve pronto!", "Chau!"]
    },
    {
      "tag": "agradecimiento",
      "patterns": ["Gracias", "Muchas gracias", "Te lo agradezco", "Genial, gracias"],
      "responses": ["¡De nada!", "Es un placer ayudarte.", "¡No hay problema!"]
    },
    {
      "tag": "nombre",
      "patterns": ["Quien sos?", "Como te llamas?", "Cual es tu nombre?"],
      "responses": ["Soy un bot de asistencia de la facultad, creado para resolver dudas.", "Mi nombre es FIUBABot, ¿en qué te ayudo?"]
    },
    {
      "tag": "inscripciones",
      "patterns": ["Cuando son las inscripciones?", "Como me inscribo a materias?", "Fechas de inscripcion", "inscripcion a finales"],
      "responses": ["Las fechas de inscripción a materias suelen ser las semanas previas al inicio del cuatrimestre. Puedes consultar el calendario académico en el sitio web de la facultad.", "Para inscripciones a finales, revisa el sistema SIU Guaraní."]
    },
    {
      "tag": "ubicacion",
      "patterns": ["Donde queda la facultad?", "Como llego?", "Direccion de la FIUBA", "Sede Las Heras", "Sede Paseo Colon"],
      "responses": ["La facultad tiene dos sedes principales: Av. Paseo Colón 850 y Av. Las Heras 2214.", "La sede de Paseo Colón es la histórica. La sede de Las Heras es más nueva."]
    },
    {
      "tag": "carreras",
      "patterns": ["Que carreras hay?", "Oferta academica", "Quiero estudiar ingenieria", "carreras de grado"],
      "responses": ["La facultad ofrece 12 carreras de grado, incluyendo Ingeniería Informática, Civil, Industrial, Mecánica, Electrónica, y más. También ofrece carreras de posgrado."]
    }
  ]
}
"""

# Escribimos el contenido al archivo
with open('intents.json', 'w', encoding='utf-8') as f:
    f.write(json_content)

print("Archivo 'intents.json' creado exitosamente.")
# Out:
# Archivo 'intents.json' creado exitosamente.

# %% [markdown]
# Cargamos el JSON y procesamos los patrones. Vamos a utilizar tokenización y lematización con NLTK

# %%
lemmatizer = WordNetLemmatizer()

words = []
classes = []
documents = []
ignore_letters = ['?', '!', '.', ',']

# Cargar el archivo JSON
with open('intents.json', 'r', encoding='utf-8') as f:
    intents = json.load(f)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        # Tokenizar
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        # Añadir a documentos (patrón, tag)
        documents.append((word_list, intent['tag']))
        # Añadir el tag a la lista de clases (si no está ya)
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# Lematizar, pasar a minúsculas y quitar puntuación
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words))) # Eliminar duplicados y ordenar

classes = sorted(list(set(classes)))

# Guardar words y classes en archivos pickle para usarlos luego
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

print("Palabras (vocabulario):", len(words))
print("Clases (intents):", len(classes))
print("\nDocumentos (patrones):", len(documents))
# Out:
# Palabras (vocabulario): 61
# Clases (intents): 7
#
# Documentos (patrones): 30

# %% [markdown]
# Convvierto nuestros patrones de texto en vectores numéricos usando el modelo Bag-of-Words (BoW) y creamos las etiquetas de salida (output) como vectores *one-hot*.

# %%
training = []
output_empty = [0] * len(classes)

for doc in documents:
    # Inicializar Bag of Words
    bag = []
    # Lista de patrones tokenizados
    pattern_words = doc[0]
    # Lematizar cada palabra
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]

    # Crear el vector BoW
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output_row es el vector one-hot
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# Mezclar los datos
random.shuffle(training)

# Separar en X (features) e Y (labels)
train_x = np.array([i[0] for i in training])
train_y = np.array([i[1] for i in training])

print("Datos de entrenamiento (X) creados. Shape:", train_x.shape)
print("Datos de salida (Y) creados. Shape:", train_y.shape)
# Out:
# Datos de entrenamiento (X) creados. Shape: (30, 61)
# Datos de salida (Y) creados. Shape: (30, 7)

# %% [markdown]
# Definimos una red neuronal secuencial simple con Keras para clasificar las intenciones.

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compilar el modelo
# Usamos SGD (Descenso de Gradiente Estocástico)
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Entrenar el modelo
hist = model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)

# Guardar el modelo
model.save('chatbot_model.h5', hist)

print("\nModelo entrenado y guardado como 'chatbot_model.h5'.")
# Out:
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2486 - loss: 1.9817
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2367 - loss: 1.9076
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1276 - loss: 1.9270
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3343 - loss: 1.8693
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1238 - loss: 1.9283
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3686 - loss: 1.7444
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2267 - loss: 1.7739
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4581 - loss: 1.7215
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3610 - loss: 1.7432
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4024 - loss: 1.6654
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3062 - loss: 1.7094
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3481 - loss: 1.5963
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5114 - loss: 1.5068
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7086 - loss: 1.4404
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7433 - loss: 1.1892
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6243 - loss: 1.3416
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6086 - loss: 1.2638
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 1.0601
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 0.9371
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8486 - loss: 0.8175
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7276 - loss: 0.8831
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7314 - loss: 0.9492
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6695 - loss: 0.9703
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7314 - loss: 0.8787
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7976 - loss: 0.8177
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7762 - loss: 0.7756
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9300 - loss: 0.5260
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9210 - loss: 0.5643
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7905 - loss: 0.5653
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9905 - loss: 0.3894
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9081 - loss: 0.5037
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8933 - loss: 0.4473
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9538 - loss: 0.3809
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9776 - loss: 0.3224
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8319 - loss: 0.4196
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9219 - loss: 0.4581
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8567 - loss: 0.3692
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8781 - loss: 0.3930
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8676 - loss: 0.3789
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9443 - loss: 0.2835
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8695 - loss: 0.4194
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1908
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8533 - loss: 0.3938
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9157 - loss: 0.3380
# Epoch 45/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9471 - loss: 0.1661
# Epoch 46/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9490 - loss: 0.2057
# Epoch 47/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9290 - loss: 0.2702
# Epoch 48/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1900
# Epoch 49/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.2915
# Epoch 50/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9848 - loss: 0.1643
# Epoch 51/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.1256
# Epoch 52/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0952
# Epoch 53/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8410 - loss: 0.3311
# Epoch 54/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1397
# Epoch 55/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9848 - loss: 0.0511
# Epoch 56/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1263
# Epoch 57/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0886
# Epoch 58/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0720
# Epoch 59/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.1376
# Epoch 60/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.1166
# Epoch 61/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9252 - loss: 0.1482
# Epoch 62/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1169
# Epoch 63/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1698
# Epoch 64/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0675
# Epoch 65/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9538 - loss: 0.2221
# Epoch 66/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.0871
# Epoch 67/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.0780
# Epoch 68/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.1289
# Epoch 69/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.1514
# Epoch 70/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9252 - loss: 0.1922
# Epoch 71/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9776 - loss: 0.1170
# Epoch 72/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.0652
# Epoch 73/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9681 - loss: 0.1211
# Epoch 74/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0456
# Epoch 75/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1004
# Epoch 76/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0474
# Epoch 77/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0905
# Epoch 78/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.1192
# Epoch 79/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0680
# Epoch 80/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9681 - loss: 0.1356
# Epoch 81/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9386 - loss: 0.1452
# Epoch 82/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1458
# Epoch 83/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9681 - loss: 0.1130
# Epoch 84/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9848 - loss: 0.0644
# Epoch 85/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9538 - loss: 0.1693
# Epoch 86/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0213
# Epoch 87/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0621
# Epoch 88/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0287
# Epoch 89/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 90/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9681 - loss: 0.1013
# Epoch 91/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0492
# Epoch 92/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8995 - loss: 0.1857
# Epoch 93/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0380
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0431
# Epoch 95/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0521
# Epoch 96/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9776 - loss: 0.0409
# Epoch 97/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.1182
# Epoch 98/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0314
# Epoch 99/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0474
# Epoch 100/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0850
# Epoch 101/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9252 - loss: 0.1083
# Epoch 102/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.0405
# Epoch 103/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 104/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 105/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0366
# Epoch 106/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0181
# Epoch 107/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0229
# Epoch 108/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0406
# Epoch 109/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9776 - loss: 0.0385
# Epoch 110/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8790 - loss: 0.1908
# Epoch 111/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0364
# Epoch 112/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 113/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0525
# Epoch 114/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0241
# Epoch 115/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8933 - loss: 0.1402
# Epoch 116/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0346
# Epoch 117/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0389
# Epoch 118/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9776 - loss: 0.0621
# Epoch 119/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0216
# Epoch 120/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0367
# Epoch 121/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9848 - loss: 0.0357
# Epoch 122/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9848 - loss: 0.0800
# Epoch 123/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 124/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0354
# Epoch 125/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0208
# Epoch 126/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0243
# Epoch 127/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9776 - loss: 0.0369
# Epoch 128/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 129/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0506
# Epoch 130/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 131/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 132/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9681 - loss: 0.0766
# Epoch 133/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.0321
# Epoch 134/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0216
# Epoch 135/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 136/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0405
# Epoch 137/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0149
# Epoch 138/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 139/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9681 - loss: 0.1041
# Epoch 140/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0275
# Epoch 141/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0239
# Epoch 142/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0528
# Epoch 143/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 144/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0300
# Epoch 145/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0419
# Epoch 146/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0835
# Epoch 147/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 148/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0342
# Epoch 149/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0548
# Epoch 150/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 151/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0693
# Epoch 152/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0270
# Epoch 153/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0203
# Epoch 154/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 155/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0165
# Epoch 156/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0573
# Epoch 157/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0299
# Epoch 158/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0079
# Epoch 159/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 160/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0113
# Epoch 161/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 162/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0215
# Epoch 163/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0549
# Epoch 164/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 165/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 166/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0511
# Epoch 167/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 168/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9681 - loss: 0.0668
# Epoch 169/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 170/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0070
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0379
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0245
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0707
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0289
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0167
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9776 - loss: 0.0366
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0424
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0166
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0363
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0057
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0748
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0256
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9776 - loss: 0.0437
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0492
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0466
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.0676
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0175
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0429
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0174
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0147
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Modelo entrenado y guardado como 'chatbot_model.h5'.

# %% [markdown]
# Creamos las funciones necesarias para procesar la entrada del usuario, predecir la intención usando el modelo entrenado y devolver una respuesta.

# %%
# Cargar los archivos pickle
words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = tf.keras.models.load_model('chatbot_model.h5')

# Función para preprocesar la entrada del usuario
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# Función para convertir la entrada en Bag of Words
def bow(sentence, words):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                bag[i] = 1
    return(np.array(bag))

# Función para predecir la clase (intent)
def predict_class(sentence, model):
    p = bow(sentence, words)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25 # Umbral de confianza
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

    # Ordenar por probabilidad
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})

    # Si no supera el umbral, devolver una respuesta por defecto
    if not return_list:
        return_list.append({"intent": "sin_respuesta", "probability": "1.0"})

    return return_list

# Función para obtener la respuesta
def get_response(ints, intents_json):
    tag = ints[0]['intent']

    if tag == "sin_respuesta":
        return "Lo siento, no entendí tu pregunta. ¿Puedes reformularla?"

    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag'] == tag):
            result = random.choice(i['responses'])
            break
    return result

# Función principal del chat
def chatbot_response(text):
    ints = predict_class(text, model)
    res = get_response(ints, intents)
    return res
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# Aca registramos las preguntas y respuestas del BOT para evaluar su desempeño, tal como solicita la consigna.

# %%
print("Iniciando chat con FIUBABot (escribe 'salir' para terminar)...")
print("-" * 50)

# Lista de preguntas para probar
preguntas_prueba = [
    "Hola",
    "como te llamas?",
    "donde queda la facultad?",
    "que carreras tienen?",
    "cuando me puedo inscribir?",
    "muchas gracias",
    "como llego a paseo colon?",
    "que es la ingenieria?", # Pregunta fuera de contexto
    "adios"
]

# Iterar sobre las preguntas de prueba y registrar las respuestas
for pregunta in preguntas_prueba:
    respuesta = chatbot_response(pregunta)
    print(f"Pregunta: {pregunta}")
    print(f"Respuesta: {respuesta}")
    print("-" * 50)
# Out:
# Iniciando chat con FIUBABot (escribe 'salir' para terminar)...
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Pregunta: Hola
# Respuesta: ¡Buen día! ¿Qué necesitas saber?
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Pregunta: como te llamas?
# Respuesta: Mi nombre es FIUBABot, ¿en qué te ayudo?
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Pregunta: donde queda la facultad?
# Respuesta: La facultad tiene dos sedes principales: Av. Paseo Colón 850 y Av. Las Heras 2214.
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Pregunta: que carreras tienen?
# Respuesta: La facultad ofrece 12 carreras de grado, incluyendo Ingeniería Informática, Civil, Industrial, Mecánica, Electrónica, y más. También ofrece carreras de posgrado.
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# Pregunta: cuando me puedo inscribir?
# Respuesta: Para inscripciones a finales, revisa el sistema SIU Guaraní.
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Pregunta: muchas gracias
# Respuesta: ¡De nada!
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Pregunta: como llego a paseo colon?
# Respuesta: La facultad tiene dos sedes principales: Av. Paseo Colón 850 y Av. Las Heras 2214.
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Pregunta: que es la ingenieria?
# Respuesta: La facultad ofrece 12 carreras de grado, incluyendo Ingeniería Informática, Civil, Industrial, Mecánica, Electrónica, y más. También ofrece carreras de posgrado.
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Pregunta: adios
# Respuesta: Adiós, ¡vuelve pronto!
# --------------------------------------------------

# %% [markdown]
# ### Análisis y Conclusiones
#
# El modelo implementado, basado en Bag-of-Words (BoW) y una Red Neuronal simple, demostró ser efectivo para clasificar un conjunto de intenciones simples y bien definidas. Respondió correctamente a interacciones sociales (saludos, despedidas) y consultas informativas (ubicación, carreras, inscripciones) siempre que la entrada del usuario se pareciera a los patrones de entrenamiento. Un aspecto clave de su funcionamiento fue el manejo de la incertidumbre: gracias al ERROR_THRESHOLD, el bot pudo identificar preguntas fuera de su vocabulario (como "¿qué es la ingeniería?") y devolver una respuesta por defecto en lugar de una incorrecta.
#
# Sin embargo, el bot presenta limitaciones claras. Su principal debilidad es la sensibilidad al vocabulario, ya que el modelo BoW no puede entender sinónimos; si un usuario utiliza una palabra no registrada (p.ej., "anotarme" en lugar de "inscribirme"), el bot fallará. Además, carece de memoria contextual, procesando cada pregunta de forma aislada. Estas limitaciones podrían abordarse añadiendo muchos más patrones de entrenamiento para cada intención o, de forma más robusta, reemplazando BoW con Word Embeddings (como los vistos en 2b y 2c con Gensim o GloVe), lo que permitiría al modelo entender relaciones semánticas y sinónimos.
